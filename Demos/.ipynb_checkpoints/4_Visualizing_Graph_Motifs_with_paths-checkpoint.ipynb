# %%
"""
Purpose: To search for motifs and then visualize
the connections in meshAfterParty or neuroglancer
"""
# Out:
# '\nPurpose: To search for motifs and then visualize\nthe connections in meshAfterParty or neuroglancer\n'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from os import sys
sys.path.append("/meshAfterParty/meshAfterParty/")

# %%
import datajoint_utils as du
import neuron_visualizations as nviz
import proofread_verification as pv
import networkx_utils as xu
# Out:
# INFO - 2021-09-21 19:58:48,968 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-09-21 19:58:48,971 - settings - Setting database.user to celiib
# INFO - 2021-09-21 19:58:48,973 - settings - Setting database.password to newceliipass
# INFO - 2021-09-21 19:58:48,974 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-09-21 19:58:48,975 - settings - Setting database.user to celiib
# INFO - 2021-09-21 19:58:48,976 - settings - Setting database.password to newceliipass
# INFO - 2021-09-21 19:58:48,981 - settings - Setting stores to {'minnie65': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65', 'stage': '/mnt/dj-stor01/platinum/minnie65'}, 'meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/meshes'}, 'decimated_meshes': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes', 'stage': '/mnt/dj-stor01/platinum/minnie65/02/decimated_meshes'}, 'skeletons': {'protocol': 'file', 'location': '/mnt/dj-stor01/platinum/minnie65/02/skeletons'}}
# INFO - 2021-09-21 19:58:48,982 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-09-21 19:58:48,994 - connection - Connected celiib@at-database.ad.bcm.edu:3306
# Connecting celiib@at-database.ad.bcm.edu:3306
# INFO - 2021-09-21 19:58:49,710 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-09-21 19:58:49,782 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-09-21 19:58:49,783 - settings - Setting database.user to celiib
# INFO - 2021-09-21 19:58:49,784 - settings - Setting database.password to newceliipass
# INFO - 2021-09-21 19:58:49,786 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-09-21 19:58:50,558 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-09-21 19:58:50,623 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-09-21 19:58:50,625 - settings - Setting database.user to celiib
# INFO - 2021-09-21 19:58:50,626 - settings - Setting database.password to newceliipass
# INFO - 2021-09-21 19:58:50,627 - settings - Setting database.host to at-database.ad.bcm.edu
# INFO - 2021-09-21 19:58:50,628 - settings - Setting database.user to celiib
# INFO - 2021-09-21 19:58:50,628 - settings - Setting database.password to newceliipass
# INFO - 2021-09-21 19:58:50,632 - settings - Setting enable_python_native_blobs to True
# INFO - 2021-09-21 19:58:51,514 - settings - Setting enable_python_native_blobs to True

# %%
import dotmotif_utils as dmu

# %% [markdown]
# # Importing the Graph

# %%
import system_utils as su
G = su.decompress_pickle("/platinum_graph/Data/G_query_v6.pbz2")

# %%
# This query will take a while
motif = """
A -> B 
B -> C
C -> A
A.cell_type = inhibitory
B.cell_type = excitatory
C.cell_type = inhibitory

"""

dmu.graph_search(motif=motif,G=G,verbose = True)

# %% [markdown]
# # Picking a specific triangle

# %%
current_triangle = {'A': '864691136830770542_0',
  'B': '864691136881594990_0',
  'C': '864691135686943200_0'}

segment_ids = list(current_triangle.values())
segment_ids
# Out:
# ['864691136830770542_0', '864691136881594990_0', '864691135686943200_0']

# %%
G[segment_ids[0]][segment_ids[1]]
# Out:
# AtlasView({0: {'postsyn_branch_idx': 1.0, 'postsyn_compartment_coarse': 'dendrite', 'postsyn_compartment_fine': 'basal', 'postsyn_limb_idx': 2.0, 'postsyn_nucleus_id': 431048, 'postsyn_skeletal_distance_to_soma': 21029.669921875, 'postsyn_spine_bouton': 'shaft', 'presyn_branch_idx': 211.0, 'presyn_compartment_coarse': 'axon', 'presyn_compartment_fine': nan, 'presyn_limb_idx': 0.0, 'presyn_nucleus_id': 432811, 'presyn_skeletal_distance_to_soma': 189499.3125, 'presyn_spine_bouton': 'bouton', 'proof_type': 'auto', 'synapse_id': 299949435, 'synapse_size': 2092, 'synapse_x': 259684, 'synapse_y': 185164, 'synapse_z': 24809, 'presyn_soma_euclid_dist': 50176.854903431326, 'postsyn_soma_euclid_dist': 28741.23810833486, 'presyn_soma_postsyn_soma_euclid_dist': 64384.34356270164, 'presyn_soma_postsyn_soma_skeletal_dist': 210528.982421875}})

# %%
G[segment_ids[1]][segment_ids[2]]
# Out:
# AtlasView({0: {'postsyn_branch_idx': 13.0, 'postsyn_compartment_coarse': 'dendrite', 'postsyn_compartment_fine': nan, 'postsyn_limb_idx': 0.0, 'postsyn_nucleus_id': 431102, 'postsyn_skeletal_distance_to_soma': 56753.80078125, 'postsyn_spine_bouton': 'shaft', 'presyn_branch_idx': 11.0, 'presyn_compartment_coarse': 'axon', 'presyn_compartment_fine': nan, 'presyn_limb_idx': 0.0, 'presyn_nucleus_id': 431048, 'presyn_skeletal_distance_to_soma': 102260.25, 'presyn_spine_bouton': 'nonbouton', 'proof_type': 'auto', 'synapse_id': 286709750, 'synapse_size': 6916, 'synapse_x': 251728, 'synapse_y': 197252, 'synapse_z': 24847, 'presyn_soma_euclid_dist': 74874.5007596044, 'postsyn_soma_euclid_dist': 54305.4662442005, 'presyn_soma_postsyn_soma_euclid_dist': 44617.216408019, 'presyn_soma_postsyn_soma_skeletal_dist': 159014.05078125}})

# %%
syn_ids = [G[segment_ids[0]][segment_ids[1]][0]["synapse_id"],
          G[segment_ids[1]][segment_ids[2]][0]["synapse_id"]]
syn_ids
# Out:
# [299949435, 286709750]

# %% [markdown]
# # Visualize in MeshAfterParty

# %%
import microns_graph_utils as mgu

mgu.visualize_graph_connections_by_method(
G,
    segment_ids = segment_ids,
    synapse_ids=syn_ids,
    method = "meshAfterParty",
    plot_synapse_skeletal_paths = True,
    verbose = False,
)
# Out:
# Compartment Colors:
#   valid_mesh:red
#   axon:red
#   dendrite:lightsteelblue
# VBox(children=(Figure(camera=PerspectiveCamera(fov=46.0, position=(0.0, 0.0, 2.0), projectionMatrix=(1.0, 0.0,…

# %%
import microns_graph_utils as mgu

mgu.visualize_graph_connections_by_method(
G,
    segment_ids = segment_ids,
    synapse_ids=syn_ids,
    method = "neuroglancer",
    plot_synapse_skeletal_paths = True,
    verbose = False,
)
# Out:
# <a href="https://neuromancer-seung-import.appspot.com/#!%7B%22jsonStateServer%22:%22https://global.daf-apis.com/nglstate/api/v1/post%22,%22navigation%22:%7B%22pose%22:%7B%22position%22:%7B%22voxelSize%22:%5B4.0,4.0,40.0%5D,%22voxelCoordinates%22:%5B251180.0,195475.25,24839.599609375%5D%7D%7D,%22zoomFactor%22:2.0%7D,%22showSlices%22:false,%22layout%22:%22xy-3d%22,%22perspectiveZoom%22:2000.0,%22layers%22:%5B%7B%22type%22:%22image%22,%22source%22:%22precomputed://https://bossdb-open-data.s3.amazonaws.com/iarpa_microns/minnie/minnie65/em%22,%22name%22:%22img%22,%22shader%22:%22#uicontrol%20float%20black%20slider(min=0,%20max=1,%20default=0.35)%5Cn#uicontrol%20float%20white%20slider(min=0,%20max=1,%20default=0.65)%5Cnfloat%20rescale(float%20value)%20%7B%5Cn%20%20return%20(value%20-%20black)%20/%20(white%20-%20black);%5Cn%7D%5Cnvoid%20main()%20%7B%5Cn%20%20float%20val%20=%20toNormalized(getDataValue());%5Cn%20%20if%20(val%20%3C%20black)%20%7B%5Cn%20%20%20%20emitRGB(vec3(0,0,0));%5Cn%20%20%7D%20else%20if%20(val%20%3E%20white)%20%7B%5Cn%20%20%20%20emitRGB(vec3(1.0,%201.0,%201.0));%5Cn%20%20%7D%20else%20%7B%5Cn%20%20%20%20emitGrayscale(rescale(val));%5Cn%20%20%7D%5Cn%7D%5Cn%22%7D,%7B%22type%22:%22segmentation_with_graph%22,%22source%22:%22graphene://https://minnie.microns-daf.com/segmentation/table/minnie3_v1%22,%22name%22:%22seg%22,%22segments%22:%5B%22864691135686943200%22,%22864691136881594990%22,%22864691136830770542%22%5D,%22segmentColors%22:%7B%22864691136830770542%22:%22blue%22,%22864691136881594990%22:%22green%22,%22864691135686943200%22:%22red%22%7D,%22objectAlpha%22:0.3%7D,%7B%22type%22:%22annotation%22,%22linkedSegmentationLayer%22:%22seg%22,%22filterBySegmentation%22:false,%22bracketShortcutsShowSegmentation%22:true,%22annotationSelectionShowsSegmentation%22:true,%22annotationColor%22:%22#ff0000%22,%22name%22:%22presyn%22,%22annotationTags%22:%5B%7B%22id%22:1,%22label%22:%22valid%22%7D,%7B%22id%22:2,%22label%22:%22not_valid%22%7D,%7B%22id%22:3,%22label%22:%22proof%22%7D%5D,%22annotations%22:%5B%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B259684.0,185164.0,24809.0%5D,%22id%22:%222611e1404e3d3aa350164130ed49610d46890453%22,%22segments%22:%5B%5D%7D,%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B251728.0,197252.0,24847.0%5D,%22id%22:%22c2271de85ecde3ba2a725e43e91e04cb22cdf105%22,%22segments%22:%5B%5D%7D%5D%7D,%7B%22type%22:%22annotation%22,%22linkedSegmentationLayer%22:%22seg%22,%22filterBySegmentation%22:false,%22bracketShortcutsShowSegmentation%22:true,%22annotationSelectionShowsSegmentation%22:true,%22annotationColor%22:%22#0000ff%22,%22name%22:%22neuron_0%22,%22annotationTags%22:%5B%7B%22id%22:1,%22label%22:%22valid%22%7D,%7B%22id%22:2,%22label%22:%22not_valid%22%7D,%7B%22id%22:3,%22label%22:%22proof%22%7D%5D,%22annotations%22:%5B%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B254717.0,196467.0,24587.0%5D,%22id%22:%229303a232e2df6f1949b525b63a143c2ca8784c07%22,%22segments%22:%5B%5D%7D%5D%7D,%7B%22type%22:%22annotation%22,%22linkedSegmentationLayer%22:%22seg%22,%22filterBySegmentation%22:false,%22bracketShortcutsShowSegmentation%22:true,%22annotationSelectionShowsSegmentation%22:true,%22annotationColor%22:%22#008000%22,%22name%22:%22neuron_1%22,%22annotationTags%22:%5B%7B%22id%22:1,%22label%22:%22valid%22%7D,%7B%22id%22:2,%22label%22:%22not_valid%22%7D,%7B%22id%22:3,%22label%22:%22proof%22%7D%5D,%22annotations%22:%5B%7B%22tagIds%22:%5B%5D,%22type%22:%22point%22,%22point%22:%5B259826.0,181767.0,24176.0%5D,%22id%22:%221e546c7feacce21ae60e0b87d6ca6674d7ade166%22,%22segments%22:%5B%5D%7D%5D%7D,%7B%22type%22:%22annotation%22,%22linkedSegmentationLayer%22:%22seg%22,%22filterBySegmentation%22:false,%22bracketShortcutsShowSegmentation%22:true,%22annotationSelectionShowsSegmentation%22:true,%22annotationColor%22:%22#ff0000%22,%22name%22:%22neuron_2%22,%22annotationTags%22:%5B%7B%22id%22:1,%22label%22:%22valid%22%7D,%7B%22id%22:2,%22label%22:%22not_valid%22%7D,%7B%22id%22:3,%22label%22:%22pr ...
